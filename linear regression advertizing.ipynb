# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
    df=pd.read_csv('advertising.csv')
    df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
X=df.drop('Sales',axis=1)

# %%
y=df['Sales']

# %%
X
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
df.plot(kind='box',subplots=True,layout=(2,2),sharex=False,sharey=False)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
df.hist()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0,test_size=0.2)

# %%
len(y_test)
# Out:
# 40

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
prediction=model.predict(X_test)

# %%
prediction
# Out:
# array([10.70988945,  8.68629773,  9.5778695 , 24.86207988, 14.65584473,
#         8.3214275 , 10.43048002, 18.4453765 ,  9.73394291, 17.9290798 ,
#        23.369886  , 10.67916356, 13.44032325, 17.17416235, 11.77380187,
#        13.37072678, 21.26009906,  9.19666875, 14.13201846, 18.9260716 ,
#        24.75507991, 12.48481182, 16.57130583, 13.77344772,  7.79299106,
#        15.19648316, 14.71607944, 20.73862119, 17.01041859,  8.83474391,
#        12.09424377, 20.74886454, 21.26147987, 21.90420095,  7.08087067,
#         7.04431681,  9.15949871, 15.47796148, 13.28282334,  7.23769883])

# %%
print(y_test)
# Out:
# 18     11.3
# 170     8.4
# 107    12.0
# 98     25.4
# 177    16.7
# 182     8.7
# 5       7.2
# 146    18.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    15.5
# 154    20.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     16.1
# 159    12.9
# 60      8.1
# 123    15.2
# 179    17.6
# 185    22.6
# 122    16.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      17.9
# 83     13.6
# 106     7.2
# Name: Sales, dtype: float64

# %%
model.score(X_test,y_test)
# Out:
# 0.8645053923967724

# %%
model.predict([[160,34,95]])
# Out:
# /Users/amolegbesunday/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16.8202982])

# %%
model.predict([[116.76,188.056,45.98]])
# Out:
# /Users/amolegbesunday/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31.85260014])

# %%
import numpy as np

# %%
from sklearn import metrics
print('MAE',metrics.mean_absolute_error(y_test,prediction))
print('MSE',metrics.mean_squared_error(y_test,prediction))
print('MAE',np.sqrt(metrics.mean_absolute_error(y_test,prediction)))
# Out:
# MAE 1.4170313030600667
# MSE 4.522552562041292
# MAE 1.190391239492322

# %%
import numpy as np

# %%
print('MAE',metrics.mean_absolute_error(y_test,prediction))
# Out:
# MAE 1.4170313030600667

# %%
print('MSE',metrics.mean_squared_error(y_test,prediction))
# Out:
# MSE 4.522552562041292

# %%
print('MAE',np.sqrt(metrics.mean_absolute_error(y_test,prediction)))
# Out:
# MAE 1.190391239492322
